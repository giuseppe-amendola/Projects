# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv ('training.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   well_name  460 non-null    object
#  1   long       460 non-null    float64
#  2   lat        460 non-null    float64
#  3   augila     460 non-null    float64
#  4   gialo      460 non-null    float64
#  5   gir        460 non-null    float64
#  6   zelten     460 non-null    float64
#  7   kalash     460 non-null    float64
#  8   sirte      460 non-null    float64
#  9   nubian     460 non-null    float64
#  10  gargaf     460 non-null    float64
#  11  basement   460 non-null    float64
#  12  seebase    460 non-null    float64
#  13  sub-basin  460 non-null    object
# dtypes: float64(12), object(2)
# memory usage: 50.4+ KB

# %%
data.describe()
# Out:
#              long         lat      augila       gialo         gir      zelten  \
# count  460.000000  460.000000  460.000000  460.000000  460.000000  460.000000
# mean    20.848806   28.240978   84.402446  401.241479  516.048160  143.151915
# std      1.205727    0.455472   20.405970   76.578497   70.574880   27.612292
# min     17.179581   27.022159   22.957815  169.540966  320.915630   73.146793
# 25%     19.904061   28.008980   78.505243  348.644385  480.240338  135.399902
# 50%     21.207896   28.202318   85.666606  385.131675  510.744331  135.402951
# 75%     21.845226   28.397013   90.639478  435.435717  547.357352  150.457206
# max     23.676663   29.572467  147.970007  640.593758  728.374177  206.739210
#
#            kalash       sirte      nubian      gargaf     basement  \
# count  460.000000  460.000000  460.000000  460.000000   460.000000
# mean    81.461450  133.086182  158.473757   70.766494 -2511.615844
# ...

# %%
# generating pairwise correlation
corr = data.corr()
  
# Displaying dataframe as an heatmap 
corr.style.background_gradient(cmap ='bwr_r',vmin=-1,vmax=1)
# Out:
# <style  type="text/css" >
# #T_0ab54_row0_col0,#T_0ab54_row1_col1,#T_0ab54_row2_col2,#T_0ab54_row3_col3,#T_0ab54_row4_col4,#T_0ab54_row5_col5,#T_0ab54_row6_col6,#T_0ab54_row7_col7,#T_0ab54_row8_col8,#T_0ab54_row9_col9,#T_0ab54_row10_col10,#T_0ab54_row11_col11{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_0ab54_row0_col1,#T_0ab54_row0_col5,#T_0ab54_row1_col0,#T_0ab54_row2_col3,#T_0ab54_row3_col2,#T_0ab54_row5_col0,#T_0ab54_row6_col7,#T_0ab54_row7_col6{
#             background-color:  #ffeaea;
#             color:  #000000;
#         }#T_0ab54_row0_col2,#T_0ab54_row2_col0{
#             background-color:  #dedeff;
#             color:  #000000;
#         }#T_0ab54_row0_col3,#T_0ab54_row3_col0{
#             background-color:  #b2b2ff;
#             color:  #000000;
#         }#T_0ab54_row0_col4,#T_0ab54_row4_col0{
#             background-color:  #ffdede;
#             color:  #000000;
# ...

# %%
#Generating pairplot using seaborn 

sns.pairplot(data)
